# %%
import pandas as pd
import os
import numpy as np
import matplotlib.pyplot as plt

path_dir = 'load_raw'
file_list = os.listdir(path_dir)
dataframes = []

for file in file_list:
    file_path = os.path.join(path_dir,file)
    df = pd.read_excel(file_path)
    dataframes.append(df)
print(dataframes[0])
# Out:
#            전력량 일보 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0             NaN        NaN        NaN        NaN        NaN        NaN
# 1             NaN        NaN        NaN        NaN        NaN        NaN
# 2             NaN        NaN        NaN        NaN        NaN        NaN
# 3             NaN        NaN        NaN        NaN        NaN        NaN
# 4             NaN        NaN        NaN        NaN        NaN        NaN
# 5   2022년 07월 01일        NaN        NaN        NaN        NaN        NaN
# 6              구분       SV-2        NaN        NaN        NaN        NaN
# 7             NaN      전압 RS      전압 ST      전압 TR       전류 R       전류 S
# 8              시간         KV         KV         KV          A          A
# 9             00시       22.8       22.9       22.8       91.1       96.2
# 10            01시       23.0       23.1       22.9       91.1       96.0
# 11            02시       22.8       22.9       22.7       83.8       88.6
# 12            03시       22.9       22.9       22.8       85.2       89.6
# 13            04시       22.9       22.9       22.8       82.8       87.3
# 14            05시       22.9       23.0       22.8       83.4       86.6
# 15            06시       22.8       22.9       22.7       80.2       84.5
# 16            07시       22.6       22.7       22.6       88.1       92.5
# 17            08시       22.5       22.5       22.4       95.4       98.0
# 18            09시       22.6       22.5       22.5      114.3      117.1
# 19            10시       22.9       22.9       22.8      117.4      120.8
# 20            11시       22.9       22.8       22.8      119.5      123.7
# 21            12시       22.7       22.7       22.6      121.9      125.5
# 22            13시       22.7       22.7       22.6      121.0      123.9
# 23            14시       22.7       22.7       22.6      125.3      129.6
# 24            15시       22.7       22.7       22.6      115.0      119.7
# 25            16시       22.7       22.7       22.6      120.9      124.9
# 26            17시       22.8       22.9       22.8      108.6      114.3
# 27            18시       22.8       22.8       22.7      101.3      107.2
# 28            19시       22.6       22.7       22.6       88.7       94.1
# 29            20시       22.8       22.9       22.7       92.4       97.8
# 30            21시       22.8       22.9       22.7       87.1       93.2
# 31            22시       22.9       23.0       22.9       84.8       90.1
# 32            23시       22.8       22.9       22.7       82.1       87.5
#
#    Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 144 Unnamed: 145  \
# 0         NaN        NaN        NaN        NaN  ...          NaN          NaN
# 1         NaN        NaN        NaN        NaN  ...          NaN          NaN
# 2         NaN        NaN        NaN        NaN  ...          NaN          NaN
# 3         NaN        NaN        NaN        NaN  ...          NaN          NaN
# 4         NaN        NaN        NaN        NaN  ...          NaN          NaN
# 5         NaN        NaN        NaN        NaN  ...          NaN          NaN
# 6         NaN        NaN        NaN        NaN  ...     중앙P/P(E)          NaN
# 7        전류 T       유효전력       무효전력      유효전력량  ...         전류 R         전류 S
# 8           A         KW       KVAR        MWH  ...            A            A
# 9        92.8     3602.5      959.0      426.3  ...          4.6          5.3
# 10       92.8     3626.3      959.0      429.8  ...          4.9          5.8
# 11       85.2     3502.8      874.5      433.2  ...          5.1          5.8
# 12       86.5     3421.8      871.8      436.5  ...          4.7          5.4
# 13       84.7     3399.3      892.8      439.8  ...          4.7          5.5
# 0           NaN          NaN          NaN
# 1           NaN          NaN          NaN
# 2           NaN          NaN          NaN
# 3           NaN          NaN          NaN
# 4           NaN          NaN          NaN
# 5           NaN          NaN          NaN
# 6           NaN          NaN          NaN
# 7          전류 T         유효전력        유효전력량
# 8             A           KW          MWH
# 9           5.2         63.1        286.0
# 10          5.2         61.7        286.0
# 11          5.2         61.2        286.1
# 12          4.9         60.8        286.1
# 13          5.2         62.3        286.2
# 14          5.0         64.1        286.3
# 15          5.5         71.8        286.3
# 16          6.3         79.0        286.4
# 17          6.2        102.2        286.5
# 18          8.5        113.2        286.5
# 19          9.4        110.5        286.6
# 20          9.6        117.6        286.7
# 21          9.3        119.1        286.8
# 22          8.5        101.4        286.9
# 23          8.0        106.4        287.0
# 24          7.7         95.6        287.1
# 25          8.4        103.2        287.2
# 26          7.6         90.3        287.3
# 27          6.4         65.9        287.4
# 28          5.2         60.0        287.5
# 29          4.8         56.9        287.5
# 30          4.9         54.7        287.6
# 31          4.9         55.1        287.6
# 32          4.5         54.5        287.7
#
# [33 rows x 154 columns]

# %%
column_name = 'Unnamed: '
load_data = []
load_sum = 0
load_col = []
for i in range(1,len(dataframes[0].columns)):
    if(dataframes[0][column_name+str(i)][7]=='유효전력'):
        load_col.append(str(i))
print(load_col)
for q in range(0,len(dataframes)):
    load_data.append([])
    for f in range(9,33):
        load_sum=0
        for i in load_col:
            load_sum+=float(dataframes[q][column_name+i][f])
        load_data[q].append(round(load_sum,1))
load_np = np.array(load_data)
print(load_np)
# Out:
# ['7', '18', '29', '37', '42', '47', '52', '57', '62', '67', '72', '77', '82', '87', '92', '97', '102', '107', '112', '117', '122', '127', '132', '137', '142', '147', '152']
# [[16920.2 16642.2 16255.2 ... 16669.6 16299.7 16121.1]
#  [15630.3 15429.4 14950.1 ... 16884.8 16721.1 16173.6]
#  [15981.6 15569.9 15399.1 ... 17228.8 16926.9 16726. ]
#  ...
#  [ 5690.3  5453.6  5334.6 ...  5099.5  5097.5  4862.5]
#  [ 4787.4  4646.5  4469.4 ...  5645.6  5438.2  5302.8]
#  [ 5173.2  5020.6  4774.1 ...  5380.9  5297.2  5072.1]]

# %%
plt.plot(load_data[0])
plt.plot(load_data[1])
plt.plot(load_data[2])
plt.plot(load_data[3])
plt.plot(load_data[4])
plt.plot(load_data[5])
plt.plot(load_data[6])
plt.plot(load_data[7])
plt.plot(load_data[8])
plt.plot(load_data[9])
plt.plot(load_data[10])

# %%
load_np = np.array(load_data)
print(np.max(load_np))
print(np.min(load_np))

print(np.unravel_index(np.argmin(load_np), load_np.shape))
print(file_list[122])
# Out:
# 25738.6
# 4354.8
# (122, 4)
# 학사 일보.gcf_2022-08-30_23-59.xls

# %%
plt.plot(load_data[61])
plt.plot(load_data[121])
plt.plot(load_data[122])
plt.plot(load_data[123])
print(file_list[61])
# Out:
# 석사 일보.gcf_2022-08-31_23-59.xls
